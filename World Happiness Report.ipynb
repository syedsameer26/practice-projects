# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/samir/Downloads/World Happiness Report 2022.csv")
df
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland            7.821         7.886        7.756
# 1       2      Denmark            7.636         7.710        7.563
# 2       3      Iceland            7.557         7.651        7.464
# 3       4  Switzerland            7.512         7.586        7.437
# 4       5  Netherlands            7.415         7.471        7.359
# ..    ...          ...              ...           ...          ...
# 141   142    Botswana*            3.471         3.667        3.275
# 142   143      Rwanda*            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# 144   145      Lebanon            2.955         3.049        2.862
# 145   146  Afghanistan            2.404         2.469        2.339
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                         2.518                         1.892
# ...

# %%
df.isnull().sum()
# Out:
# RANK                                          0
# Country                                       0
# Happiness score                               0
# Whisker-high                                  0
# Whisker-low                                   0
# Dystopia (1.83) + residual                    0
# Explained by: GDP per capita                  0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %%
sns.relplot(x = 'Happiness score', y = 'Explained by: GDP per capita' , data = df, hue = 'Country')
plt.figure(figsize = [15, 7])
plt.show()

# %%
gdp_top = df.head().groupby('Country')['Happiness score'].sum()
gdp_top
# Out:
# Country
# Denmark        7.636
# Finland        7.821
# Iceland        7.557
# Netherlands    7.415
# Switzerland    7.512
# Name: Happiness score, dtype: float64

# %%
gdp_top.plot.pie(figsize = (20,10), fontsize = 10, autopct = '%.3f')
plt.show()

# %%
gdp_b = df.tail().groupby('Country')['Happiness score'].sum()
gdp_b
# Out:
# Country
# Afghanistan    2.404
# Botswana*      3.471
# Lebanon        2.955
# Rwanda*        3.268
# Zimbabwe       2.995
# Name: Happiness score, dtype: float64

# %%
gdp_b.plot.pie(figsize = (20 , 10), fontsize = 10, autopct = '%.3f')
plt.show()

# %%
corr_mat = df.corr()
plt.figure(figsize=[20,10])
sns.heatmap(corr_mat,annot=True)
plt.title("correlation Matrix")
plt.show()

# %%
sns.relplot(x = 'Happiness score', y = 'Explained by: GDP per capita' , data = df, hue = 'Country')
plt.figure(figsize = [20, 15])
plt.show()

# %%
ss_1 = df.head().groupby('Country')['Explained by: Social support'].sum()
ss_1
# Out:
# Country
# Denmark        1.243
# Finland        1.258
# Iceland        1.320
# Netherlands    1.206
# Switzerland    1.226
# Name: Explained by: Social support, dtype: float64

# %%
ss_1.plot.pie(figsize = (20 , 10), fontsize = 10, autopct = '%.3f')
plt.show()

# %%
sns.relplot(x = 'Happiness score', y = 'Explained by: Healthy life expectancy' , data = df, hue = 'Country')
plt.figure(figsize = [30 , 20])
plt.show()

# %%
hle = df.head().groupby('Country')['Explained by: Healthy life expectancy'].sum()
hle
# Out:
# Country
# Denmark        0.777
# Finland        0.775
# Iceland        0.803
# Netherlands    0.787
# Switzerland    0.822
# Name: Explained by: Healthy life expectancy, dtype: float64

# %%
hle.plot.pie(figsize = (20 , 10), fontsize = 10, autopct = '%.3f')
plt.show()

# %%
sns.relplot(x = 'Happiness score', y = 'Explained by: Freedom to make life choices' , data = df, hue = 'Country')
plt.figure(figsize = [20,30])
plt.show()

# %%
freedom = df.head().groupby('Country')['Explained by: Freedom to make life choices'].sum()
freedom
# Out:
# Country
# Denmark        0.719
# Finland        0.736
# Iceland        0.718
# Netherlands    0.651
# Switzerland    0.677
# Name: Explained by: Freedom to make life choices, dtype: float64

# %%
freedom.plot.pie(figsize = (20 , 10), fontsize = 10, autopct = '%.3f')
plt.show()

# %%
sns.relplot(x = 'Happiness score', y = 'Explained by: Generosity' , data = df, hue = 'Country')
plt.figure(figsize = [30 , 20])
plt.show()

# %%
generosity = df.head().groupby('Country')['Explained by: Generosity'].sum()
generosity
# Out:
# Country
# Denmark        0.188
# Finland        0.109
# Iceland        0.270
# Netherlands    0.271
# Switzerland    0.147
# Name: Explained by: Generosity, dtype: float64

# %%
generosity.plot.pie(figsize = (20 , 10), fontsize = 10, autopct = '%.3f')
plt.show()

# %%
sns.relplot(x = 'Happiness score', y = 'Explained by: Perceptions of corruption' , data = df, hue = 'Country')
plt.figure(figsize = [30 , 20])
plt.show()

# %%
corru = df.head().groupby('Country')['Explained by: Perceptions of corruption'].sum()
corru
# Out:
# Country
# Denmark        0.532
# Finland        0.534
# Iceland        0.191
# Netherlands    0.419
# Switzerland    0.461
# Name: Explained by: Perceptions of corruption, dtype: float64

# %%
corru.plot.pie(figsize = (20 , 10), fontsize = 10, autopct = '%.3f')
plt.show()
